# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q einops
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.6 MB/s eta 0:00:00

# %%
# %cd "/content/drive/MyDrive/SkinFormer"
# Out:
# /content/drive/MyDrive/SkinFormer

# %%
# %cd "/content/drive/MyDrive/UNSW/SkinFormer"
# Out:
# /content/drive/.shortcut-targets-by-id/15pWwDX5nsgZf9UiVMkjZ1HH_FdlMbNq8/SkinFormer

# %%
# !python Train_DeiT-S_LRP.py --config configs.yml
# Out:
# CUDA is available: True
#
# Starting...
#
# {'train': 12809, 'val': 3203}
# VisionTransformer(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#   )
#   (blocks): ModuleList(
#     (0-11): 12 x Block(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (matmul1): einsum()
#         (matmul2): einsum()
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#         (softmax): Softmax(dim=-1)
#       )
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#       (add1): Add()
#       (add2): Add()
#       (clone1): Clone()
#       (clone2): Clone()
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (head): Linear(in_features=384, out_features=3, bias=True)
#   (pool): IndexSelect()
#   (add): Add()
# )

# %%
# !python Train_DeiT-S.py --config configs.yml
# Out:
# CUDA is available: True
#
# Starting...
#
# {'train': 12809, 'val': 3203}
# Downloading: "https://dl.fbaipublicfiles.com/deit/deit_small_patch16_224-cd65a155.pth" to /root/.cache/torch/hub/checkpoints/deit_small_patch16_224-cd65a155.pth
# 100% 84.2M/84.2M [00:00<00:00, 196MB/s]
# DeiT_S(
#   (backbone): VisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (fc): Identity()
#   )
#   (fc): Linear(in_features=384, out_features=3, bias=True)
# )
# Resuming training from: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 29/39
# --------------------
# Current phase: train
# train Loss: 0.0541 Acc: 0.9884 Balanced Accuracy: 0.9886
# Current phase: val
# val Loss: 0.6057 Acc: 0.8345 Balanced Accuracy: 0.7382
# New leading accuracy: 0.8345301151275635
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 30/39
# --------------------
# Current phase: train
# train Loss: 0.0454 Acc: 0.9906 Balanced Accuracy: 0.9906
# Current phase: val
# val Loss: 0.6256 Acc: 0.8308 Balanced Accuracy: 0.7385
# Epoch 31/39
# --------------------
# Current phase: train
# train Loss: 0.0397 Acc: 0.9914 Balanced Accuracy: 0.9913
# Current phase: val
# val Loss: 0.6472 Acc: 0.8286 Balanced Accuracy: 0.7503
# Epoch 32/39
# --------------------
# Current phase: train
# train Loss: 0.0361 Acc: 0.9923 Balanced Accuracy: 0.9923
# Current phase: val
# val Loss: 0.6523 Acc: 0.8352 Balanced Accuracy: 0.7418
# New leading accuracy: 0.8351545333862305
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 33/39
# --------------------
# Current phase: train
# train Loss: 0.0308 Acc: 0.9941 Balanced Accuracy: 0.9943
# Current phase: val
# val Loss: 0.6781 Acc: 0.8317 Balanced Accuracy: 0.7330
# Epoch 34/39
# --------------------
# Current phase: train
# train Loss: 0.0305 Acc: 0.9934 Balanced Accuracy: 0.9935
# Current phase: val
# val Loss: 0.7205 Acc: 0.8208 Balanced Accuracy: 0.7513
# Epoch 35/39
# --------------------
# Current phase: train
# train Loss: 0.0276 Acc: 0.9936 Balanced Accuracy: 0.9935
# Current phase: val
# val Loss: 0.7092 Acc: 0.8236 Balanced Accuracy: 0.7388
# Epoch 36/39
# --------------------
# Current phase: train
# train Loss: 0.0200 Acc: 0.9959 Balanced Accuracy: 0.9961
# Current phase: val
# val Loss: 0.7145 Acc: 0.8327 Balanced Accuracy: 0.7315
# Epoch 37/39
# --------------------
# Current phase: train
# train Loss: 0.0183 Acc: 0.9970 Balanced Accuracy: 0.9969
# Current phase: val
# val Loss: 0.7399 Acc: 0.8295 Balanced Accuracy: 0.7429
# Epoch 38/39
# --------------------
# Current phase: train
# train Loss: 0.0376 Acc: 0.9888 Balanced Accuracy: 0.9888
# Current phase: val
# val Loss: 0.7420 Acc: 0.8249 Balanced Accuracy: 0.7290
# Epoch 39/39
# --------------------
# Current phase: train
# train Loss: 0.0389 Acc: 0.9883 Balanced Accuracy: 0.9884
# Current phase: val
# val Loss: 0.7084 Acc: 0.8383 Balanced Accuracy: 0.7385
# New leading accuracy: 0.8382765650749207
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Training complete in 118m 31s
# Best val Loss: 0.708395
# Best val Acc: 0.838277
# Best val Balanced Acc: 0.738523
#
#  Final Validation results for BASE: Accuracy: 0.8382766156728068  Balanced Accuracy: 0.7385233418396776
#
# {'acc_avg': 0.8382766156728068, 'acc_per_type': array([0.80434783, 0.80498375, 0.84156977, 0.89316988, 0.89320388,
#        0.84210526]), 'PQD': 0.9005198487712666, 'DPM': 0.4229887507883128, 'EOM': 0.6125350511557408, 'AUC': -1}
