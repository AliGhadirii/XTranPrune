# %%
# %cd "/content/drive/MyDrive/SkinFormer"
# Out:
# /content/drive/MyDrive/SkinFormer

# %%
# !python Train_DeiT-S.py --config configs.yml
# Out:
# CUDA is available: True
#
# Starting...
#
# {'train': 12809, 'val': 3203}
# Downloading: "https://dl.fbaipublicfiles.com/deit/deit_small_patch16_224-cd65a155.pth" to /root/.cache/torch/hub/checkpoints/deit_small_patch16_224-cd65a155.pth
# 100% 84.2M/84.2M [00:01<00:00, 52.6MB/s]
# DeiT_S(
#   (backbone): VisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (fc): Identity()
#   )
#   (fc): Linear(in_features=384, out_features=3, bias=True)
# )
# Resuming training from: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 20/29
# --------------------
# Current phase: train
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:2184: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# train Loss: 0.2089 Acc: 0.9333 Balanced Accuracy: 0.9330
# Current phase: val
# val Loss: 0.5614 Acc: 0.7958 Balanced Accuracy: 0.7307
# New leading accuracy: 0.7958164215087891
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 21/29
# --------------------
# Current phase: train
# train Loss: 0.1863 Acc: 0.9424 Balanced Accuracy: 0.9416
# Current phase: val
# val Loss: 0.5743 Acc: 0.7952 Balanced Accuracy: 0.7418
# Epoch 22/29
# --------------------
# Current phase: train
# train Loss: 0.1654 Acc: 0.9522 Balanced Accuracy: 0.9520
# Current phase: val
# val Loss: 0.5712 Acc: 0.8033 Balanced Accuracy: 0.7502
# New leading accuracy: 0.8033093810081482
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 23/29
# --------------------
# Current phase: train
# train Loss: 0.1475 Acc: 0.9578 Balanced Accuracy: 0.9575
# Current phase: val
# val Loss: 0.5545 Acc: 0.8167 Balanced Accuracy: 0.7421
# New leading accuracy: 0.8167343139648438
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 24/29
# --------------------
# Current phase: train
# train Loss: 0.1301 Acc: 0.9634 Balanced Accuracy: 0.9640
# Current phase: val
# val Loss: 0.5797 Acc: 0.8071 Balanced Accuracy: 0.7258
# Epoch 25/29
# --------------------
# Current phase: train
# train Loss: 0.1153 Acc: 0.9671 Balanced Accuracy: 0.9674
# Current phase: val
# val Loss: 0.5702 Acc: 0.8183 Balanced Accuracy: 0.7428
# New leading accuracy: 0.8182953000068665
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 26/29
# --------------------
# Current phase: train
# train Loss: 0.0979 Acc: 0.9737 Balanced Accuracy: 0.9736
# Current phase: val
# val Loss: 0.5891 Acc: 0.8155 Balanced Accuracy: 0.7450
# Epoch 27/29
# --------------------
# Current phase: train
# train Loss: 0.0851 Acc: 0.9779 Balanced Accuracy: 0.9781
# Current phase: val
# val Loss: 0.5920 Acc: 0.8202 Balanced Accuracy: 0.7426
# New leading accuracy: 0.8201685547828674
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 28/29
# --------------------
# Current phase: train
# train Loss: 0.0717 Acc: 0.9815 Balanced Accuracy: 0.9815
# Current phase: val
# val Loss: 0.5915 Acc: 0.8289 Balanced Accuracy: 0.7353
# New leading accuracy: 0.8289103507995605
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 29/29
# --------------------
# Current phase: train
# train Loss: 0.0682 Acc: 0.9829 Balanced Accuracy: 0.9829
# Current phase: val
# val Loss: 0.6247 Acc: 0.8239 Balanced Accuracy: 0.7376
# Training complete in 137m 45s
# Best val Loss: 0.591512
# Best val Acc: 0.828910
# Best val Balanced Acc: 0.735308
#
#  Final Validation results for BASE: Accuracy: 0.8289103965032781  Balanced Accuracy: 0.7353082928536046
#
# {'acc_avg': 0.8289103965032781, 'acc_per_type': array([0.79264214, 0.79089924, 0.83866279, 0.89141856, 0.8802589 ,
#        0.81578947]), 'PQD': 0.8872366737830641, 'DPM': 0.5327549770875549, 'EOM': 0.6310689955764371, 'AUC': -1}

# %%
# !python Train_DeiT-S.py --config configs.yml
# Out:
# CUDA is available: True
#
# Starting...
#
# {'train': 12809, 'val': 3203}
# Downloading: "https://dl.fbaipublicfiles.com/deit/deit_small_patch16_224-cd65a155.pth" to /root/.cache/torch/hub/checkpoints/deit_small_patch16_224-cd65a155.pth
# 100% 84.2M/84.2M [00:00<00:00, 196MB/s]
# DeiT_S(
#   (backbone): VisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (fc): Identity()
#   )
#   (fc): Linear(in_features=384, out_features=3, bias=True)
# )
# Resuming training from: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 29/39
# --------------------
# Current phase: train
# train Loss: 0.0541 Acc: 0.9884 Balanced Accuracy: 0.9886
# Current phase: val
# val Loss: 0.6057 Acc: 0.8345 Balanced Accuracy: 0.7382
# New leading accuracy: 0.8345301151275635
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 30/39
# --------------------
# Current phase: train
# train Loss: 0.0454 Acc: 0.9906 Balanced Accuracy: 0.9906
# Current phase: val
# val Loss: 0.6256 Acc: 0.8308 Balanced Accuracy: 0.7385
# Epoch 31/39
# --------------------
# Current phase: train
# train Loss: 0.0397 Acc: 0.9914 Balanced Accuracy: 0.9913
# Current phase: val
# val Loss: 0.6472 Acc: 0.8286 Balanced Accuracy: 0.7503
# Epoch 32/39
# --------------------
# Current phase: train
# train Loss: 0.0361 Acc: 0.9923 Balanced Accuracy: 0.9923
# Current phase: val
# val Loss: 0.6523 Acc: 0.8352 Balanced Accuracy: 0.7418
# New leading accuracy: 0.8351545333862305
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Epoch 33/39
# --------------------
# Current phase: train
# train Loss: 0.0308 Acc: 0.9941 Balanced Accuracy: 0.9943
# Current phase: val
# val Loss: 0.6781 Acc: 0.8317 Balanced Accuracy: 0.7330
# Epoch 34/39
# --------------------
# Current phase: train
# train Loss: 0.0305 Acc: 0.9934 Balanced Accuracy: 0.9935
# Current phase: val
# val Loss: 0.7205 Acc: 0.8208 Balanced Accuracy: 0.7513
# Epoch 35/39
# --------------------
# Current phase: train
# train Loss: 0.0276 Acc: 0.9936 Balanced Accuracy: 0.9935
# Current phase: val
# val Loss: 0.7092 Acc: 0.8236 Balanced Accuracy: 0.7388
# Epoch 36/39
# --------------------
# Current phase: train
# train Loss: 0.0200 Acc: 0.9959 Balanced Accuracy: 0.9961
# Current phase: val
# val Loss: 0.7145 Acc: 0.8327 Balanced Accuracy: 0.7315
# Epoch 37/39
# --------------------
# Current phase: train
# train Loss: 0.0183 Acc: 0.9970 Balanced Accuracy: 0.9969
# Current phase: val
# val Loss: 0.7399 Acc: 0.8295 Balanced Accuracy: 0.7429
# Epoch 38/39
# --------------------
# Current phase: train
# train Loss: 0.0376 Acc: 0.9888 Balanced Accuracy: 0.9888
# Current phase: val
# val Loss: 0.7420 Acc: 0.8249 Balanced Accuracy: 0.7290
# Epoch 39/39
# --------------------
# Current phase: train
# train Loss: 0.0389 Acc: 0.9883 Balanced Accuracy: 0.9884
# Current phase: val
# val Loss: 0.7084 Acc: 0.8383 Balanced Accuracy: 0.7385
# New leading accuracy: 0.8382765650749207
# Checkpoint saved: /content/drive/MyDrive/SkinFormer/Outputs/DeiT-S_checkpoint_BASE.pth
# Training complete in 118m 31s
# Best val Loss: 0.708395
# Best val Acc: 0.838277
# Best val Balanced Acc: 0.738523
#
#  Final Validation results for BASE: Accuracy: 0.8382766156728068  Balanced Accuracy: 0.7385233418396776
#
# {'acc_avg': 0.8382766156728068, 'acc_per_type': array([0.80434783, 0.80498375, 0.84156977, 0.89316988, 0.89320388,
#        0.84210526]), 'PQD': 0.9005198487712666, 'DPM': 0.4229887507883128, 'EOM': 0.6125350511557408, 'AUC': -1}
